# %%
import pandas as pd

# %%
data = pd.read_csv('~/Downloads/assignment.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0 IMBD title ID            Original titlÊ Release year Genrë¨  \
# 0           0     tt0111161  The Shawshank Redemption   1995-02-10  Drama
#
#   Duration Country Content Rating        Director  Unnamed: 8      Income  \
# 0      142     USA              R  Frank Darabont         NaN  $ 28815245
#
#       Votes  Score
# 0  2.278.845   9.3

# %% [markdown]
# - drop some unwanted columns
# - remove duplicate rows
# - change the column names
#  - make the release year consistent
#  - get the first genre
#  - make the countries consistent
#  - make the income, votes and score columns numerical data types

# %%
del df['IMBD title ID']

# %%
df.head(2)
# Out:
#              Original titlÊ Release year        Genrë¨ Duration Country  \
# 0  The Shawshank Redemption   1995-02-10         Drama      142     USA
# 1             The Godfather   09 21 1972  Crime, Drama      175     USA
#
#   Content Rating              Director       Income     Votes  Score
# 0              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %%
df.rename({'Original titlÊ':'original title', 'Genrë¨':'genre'}, axis=1, inplace=True)

# %%
df.columns = df.columns.str.lower().str.replace(' ','_')

# %%
df.head(1)
# Out:
#              original_title release_year  genre duration country  \
# 0  The Shawshank Redemption   1995-02-10  Drama      142     USA
#
#   content_rating        director      income    _votes_ score
# 0              R  Frank Darabont  $ 28815245  2.278.845   9.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    object
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   _votes_         100 non-null    object
#  9   score           100 non-null    object
# dtypes: object(10)
# memory usage: 8.0+ KB

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# original_title     1
# release_year       1
# genre              1
# duration           2
# country            1
# content_rating    24
# director           1
# income             1
# _votes_            1
# score              1
# dtype: int64

# %%
df.drop(13, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    object
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   _votes_         100 non-null    object
#  9   score           100 non-null    object
# dtypes: object(10)
# memory usage: 8.6+ KB

# %%
pd.reset_option('display.max_rows')
df.duration
# Out:
# 0      142
# 1      175
# 2      152
# 3      220
# 4
#       ...
# 96     129
# 97     149
# 98     132
# 99     123
# 100    103
# Name: duration, Length: 100, dtype: object

# %%
pd.set_option('display.max_rows', None)
df.duration.value_counts()
# Out:
# 130               3
# 149               3
# 122               3
# 137               3
# 119               3
# 116               3
# 125               2
# 117               2
# 165               2
# 102               2
# 112               2
# 106               2
# 110               2
# 155               2
# 170               2
# 132               2
# 142               2
# 115               2
# 136               2
# 169               2
# 146               2
# 103               2
# 129               1
# 228               1
# 181               1
# 128               1
# 160               1
# 147               1
# 120               1
# 114               1
# 95                1
# 178               1
# 153               1
# 126               1
# 81                1
# 105               1
# 108               1
# 99                1
# 131               1
# 98                1
# 134               1
# 229               1
# 104               1
# 150               1
# 113               1
# ...

# %%
df[df.duration == "Not Applicable"]
# Out:
# Empty DataFrame
# Columns: [original_title, release_year, genre, duration, country, content_rating, director, income, _votes_, score]
# Index: []

# %%
df.loc[16,'duration'] = 124

# %%
df[df.duration == '178c']
# Out:
#                                        original_title release_year  \
# 11  The Lord of the Rings: The Fellowship of the Ring   2002-01-18
#
#                        genre duration      country content_rating  \
# 11  Action, Adventure, Drama     178c  New Zesland          PG-13
#
#          director       income    _votes_ score
# 11  Peter Jackson  $ 887934303  1.619.920   8.8

# %%
df.loc[11,'duration'] = 178

# %%
df.head(3)
# Out:
#              original_title  release_year                 genre duration  \
# 0  The Shawshank Redemption    1995-02-10                 Drama      142
# 1             The Godfather    09 21 1972          Crime, Drama      175
# 2           The Dark Knight   23 -07-2008  Action, Crime, Drama      152
#
#   country content_rating              director        income    _votes_ score
# 0     USA              R        Frank Darabont    $ 28815245  2.278.845   9.3
# 1     USA              R  Francis Ford Coppola   $ 246120974  1.572.674   9.2
# 2      US          PG-13     Christopher Nolan  $ 1005455211  2.241.615    9.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    object
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   _votes_         100 non-null    object
#  9   score           100 non-null    object
# dtypes: object(10)
# memory usage: 12.7+ KB

# %%
df['release_year'] = pd.to_datetime(df['release_year'], errors='coerce')
# Out:
# /var/folders/bs/tyy5gc8523g_sjnq040rw84m0000gp/T/ipykernel_937/2580657854.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['release_year'] = pd.to_datetime(df['release_year'], errors='coerce')

# %%
df
# Out:
#                                         original_title release_year  \
# 0                             The Shawshank Redemption   1995-02-10
# 1                                        The Godfather   1972-09-21
# 2                                      The Dark Knight   2008-07-23
# 3                               The Godfather: Part II   1975-09-25
# 4                                         Pulp Fiction   1994-10-28
# 5        The Lord of the Rings: The Return of the King   2004-02-22
# 6                                     Schindler's List   1994-03-11
# 7                                         12 Angry Men   1957-09-04
# 8                                            Inception   2010-09-24
# 9                                           Fight Club   1999-10-29
# 10                                        Forrest Gump   1994-10-06
# 11   The Lord of the Rings: The Fellowship of the Ring   2002-01-18
# 12                     Il buono, il brutto, il cattivo   1966-12-23
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df
# Out:
#                   original_title release_year                       genre  \
# 0       The Shawshank Redemption   1995-02-10                       Drama
# 1                  The Godfather   1972-09-21                Crime, Drama
# 2                The Dark Knight   2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II   1975-09-25                Crime, Drama
# 4                   Pulp Fiction   1994-10-28                Crime, Drama
# ..                           ...          ...                         ...
# 96                     The Sting   1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot   1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹   1965-12-20                     Western
# 99       Jodaeiye Nader az Simin   2011-10-21                       Drama
# 100          Singin' in the Rain   1953-02-05    Comedy, Musical, Romance
#
#     duration       country content_rating              director  \
# ...

# %%
df.genre = df.genre.str.split(',', expand=True)[0]

# %%
df
# Out:
#                   original_title release_year      genre duration  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142
# 1                  The Godfather   1972-09-21      Crime      175
# 2                The Dark Knight   2008-07-23     Action      152
# 3         The Godfather: Part II   1975-09-25      Crime      220
# 4                   Pulp Fiction   1994-10-28      Crime
# ..                           ...          ...        ...      ...
# 96                     The Sting   1974-03-21     Comedy      129
# 97                      Das Boot   1982-03-18  Adventure      149
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123
# 100          Singin' in the Rain   1953-02-05     Comedy      103
#
#           country content_rating              director         income  \
# 0             USA              R        Frank Darabont     $ 28815245
# ...

# %%
df.country.value_counts()
# Out:
# USA            64
# UK             12
# Italy           5
# Japan           4
# New Zealand     3
# France          3
# Germany         3
# South Korea     2
# Brazil          1
# India           1
# Denmark         1
# Iran            1
# Name: country, dtype: int64

# %%
df[df['country'] == 'West Germany']
# Out:
#    original_title release_year      genre duration       country  \
# 97       Das Boot   1982-03-18  Adventure      149  West Germany
#
#    content_rating           director      income  _votes_ score
# 97              R  Wolfgang Petersen  $ 11487676  226.427   7.5

# %%
df.loc[97,'country'] = 'Germany'

# %%
df
# Out:
#                   original_title release_year      genre duration  country  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142      USA
# 1                  The Godfather   1972-09-21      Crime      175      USA
# 2                The Dark Knight   2008-07-23     Action      152      USA
# 3         The Godfather: Part II   1975-09-25      Crime      220      USA
# 4                   Pulp Fiction   1994-10-28      Crime               USA
# ..                           ...          ...        ...      ...      ...
# 96                     The Sting   1974-03-21     Comedy      129      USA
# 97                      Das Boot   1982-03-18  Adventure      149  Germany
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132    Italy
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123     Iran
# 100          Singin' in the Rain   1953-02-05     Comedy      103      USA
#
# ...

# %%
df.income = df.income.str.split(' ', expand=True)[1]

# %%
df.loc[3,'income'] = 408035783

# %%
df
# Out:
#                   original_title release_year      genre duration  country  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142      USA
# 1                  The Godfather   1972-09-21      Crime      175      USA
# 2                The Dark Knight   2008-07-23     Action      152      USA
# 3         The Godfather: Part II   1975-09-25      Crime      220      USA
# 4                   Pulp Fiction   1994-10-28      Crime               USA
# ..                           ...          ...        ...      ...      ...
# 96                     The Sting   1974-03-21     Comedy      129      USA
# 97                      Das Boot   1982-03-18  Adventure      149  Germany
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132    Italy
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123     Iran
# 100          Singin' in the Rain   1953-02-05     Comedy      103      USA
#
# ...

# %%
df.income = df.income.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    97 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   _votes_         100 non-null    object
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 12.7+ KB

# %%
df
# Out:
#                   original_title release_year      genre duration  country  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142      USA
# 1                  The Godfather   1972-09-21      Crime      175      USA
# 2                The Dark Knight   2008-07-23     Action      152      USA
# 3         The Godfather: Part II   1975-09-25      Crime      220      USA
# 4                   Pulp Fiction   1994-10-28      Crime               USA
# ..                           ...          ...        ...      ...      ...
# 96                     The Sting   1974-03-21     Comedy      129      USA
# 97                      Das Boot   1982-03-18  Adventure      149  Germany
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132    Italy
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123     Iran
# 100          Singin' in the Rain   1953-02-05     Comedy      103      USA
#
# ...

# %%
df['_votes_'] = df['_votes_'].str.replace('.','')
# Out:
# /var/folders/bs/tyy5gc8523g_sjnq040rw84m0000gp/T/ipykernel_937/1851783378.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['_votes_'] = df['_votes_'].str.replace('.','')

# %%
df
# Out:
#                   original_title release_year      genre duration  country  \
# 0       The Shawshank Redemption   1995-02-10      Drama      142      USA
# 1                  The Godfather   1972-09-21      Crime      175      USA
# 2                The Dark Knight   2008-07-23     Action      152      USA
# 3         The Godfather: Part II   1975-09-25      Crime      220      USA
# 4                   Pulp Fiction   1994-10-28      Crime               USA
# ..                           ...          ...        ...      ...      ...
# 96                     The Sting   1974-03-21     Comedy      129      USA
# 97                      Das Boot   1982-03-18  Adventure      149  Germany
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western      132    Italy
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama      123     Iran
# 100          Singin' in the Rain   1953-02-05     Comedy      103      USA
#
#     content_rating              director      income  _votes_ score
# ...

# %%
df.score.value_counts()
# Out:
# 8.6       11
# 8.2        8
# 8.3        8
# 8.1        7
# 8.4        7
# 8.5        6
# 7.5        6
# 7.8        6
# 8.0        6
# 7.9        5
# 7.6        4
# 7.7        4
# 7.4        3
# 8.8        3
# 8.7        2
# 8.9        2
# 9.2        1
# 8,6        1
# 8,7e-0     1
# 8.7.       1
# ++8.7      1
# 8:8        1
# 8..8       1
# 08.9       1
# 8,9f       1
# 9,.0       1
# 9.         1
# 9.3        1
# Name: score, dtype: int64

# %%
df[df.score == '8,7e-0']
# Out:
#                                     original_title release_year   genre  \
# 16  Star Wars: Episode V - The Empire Strikes Back   1980-09-19  Action
#
#    duration country content_rating        director     income  _votes_   score
# 16      124     USA             PG  Irvin Kershner  549265501  1132073  8,7e-0

# %%
df.loc[16,'score'] = 8.7

# %%
df.content_rating.value_counts()
# Out:
# R            45
# PG-13        12
# PG           11
# G             6
# Not Rated     1
# Approved      1
# Unrated       1
# Name: content_rating, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    97 non-null     datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   _votes_         100 non-null    object
#  9   score           100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 12.7+ KB

# %%
name = 'Peter'
if name== 'James':
    print('Hi James')
elif name == 'Gabriel':
    print('Hi Gabriel')
elif name == 'Peter':
    print('Hi Peter')
else:
    print('Hello everyone')
# Out:
# Hello everyone

# %%
=ifs(100>20, "Hi James", "Hi Gabriel")

# %% [markdown]
# - While loop and For loop

# %% [markdown]
#  - For Loop

# %%
a = [2,6,9,3]

# %%
print(a[0] * 2)
print(a[1] * 2)
print(a[2] * 2)
print(a[3] * 2)
# Out:
# 4
# 12
# 18
# 6

# %%
a
# Out:
# [2, 6, 9, 3]

# %%
for i in a:
    print(i * 2)
# Out:
# 4
# 12
# 18
# 6

# %% [markdown]
# - While loop

# %%
students = 0
while students < 5:
    print('Come in')
    students += 1
# Out:
# Come in
# Come in
# Come in
# Come in
# Come in

# %%
weight = 0
while weight < 200:
    print('What do we weight')
    x = input()
    weight += int(x)
    print('you can enter')
else:
    print('The lift has reached maximum capacity')
# Out:
# What do we weight
# 50
# you can enter
# What do we weight
# 70
# you can enter
# What do we weight
# 50
# you can enter
# What do we weight
# 60
# you can enter
# The lift has reached maximum capacity

# %% [markdown]
# - Functions

# %%
def adding_two(a,b):
    return(a+b)

# %%
adding_two(20,45)
# Out:
# 65

# %%
def lower_col(df):
    new_df = df.columns.str.lower
    print(new_df)

# %%
lower_col(data)
# Out:
# <bound method StringMethods.lower of <pandas.core.strings.accessor.StringMethods object at 0x13af01780>>

# %%
new_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 new_df
#
# NameError: name 'new_df' is not defined

# %%
adding_two(34,89)
# Out:
# 123
